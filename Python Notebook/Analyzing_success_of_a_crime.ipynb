# %%
# Data exploration
import pandas as pd

# Numerical
import numpy as np
import NYC_getCleaned_Data 
import data_utility

# %%
from NYC_getCleaned_Data import getCleanedData

# %%
crimes_original = getCleanedData()

# %%
#Drop unnecessary features
data_to_tranform = crimes_original.drop([0,1,2,3,4,6,12,13,14],axis=1)

# %%
crime_filter = data_to_tranform[7].value_counts(dropna=False)
crime_filter
# Out:
# COMPLETED    5944659
# ATTEMPTED     104137
# Name: 7, dtype: int64

# %%
from data_utility import filterData,getCount,sortValue

# %%
completed_crimes = filterData(data_to_tranform,7,'COMPLETED')

# %%
sortFelony = sortValue(filterData(getCount(completed_crimes,list([9,11,8]),'FELONY'),8,'FELONY'),'FELONY',False)
sortVio = sortValue(filterData(getCount(completed_crimes,list([9,11,8]),'VIOLATION'),8,'VIOLATION'),'VIOLATION',False)
sortMis = sortValue(filterData(getCount(completed_crimes,list([9,11,8]),'MISDEMEANOR'),8,'MISDEMEANOR'),'MISDEMEANOR',False)
mergedData = sortFelony.merge(sortMis.merge(sortVio, left_on=[9,11], right_on=[9,11], how='outer'), left_on=[9,11], right_on=[9,11], how='outer')

# %%
final = mergedData.drop([8,'8_x','8_y'],axis=1)
final.columns = ['Boroughs', 'Premises', 'Felony', 'Misdemeanor', 'Violation']
final
# Out:
#           Boroughs                    Premises    Felony  Misdemeanor  \
# 0         BROOKLYN                      STREET  206125.0     361936.0
# 1           QUEENS                      STREET  139405.0     221115.0
# 2            BRONX                      STREET  132332.0     301710.0
# 3         BROOKLYN      RESIDENCE - APT. HOUSE  129503.0     198286.0
# 4        MANHATTAN                      STREET  117193.0     249406.0
# 5        MANHATTAN      RESIDENCE - APT. HOUSE   89436.0     118836.0
# 6            BRONX      RESIDENCE - APT. HOUSE   87557.0     194144.0
# 7           QUEENS             RESIDENCE-HOUSE   78668.0     107858.0
# 8           QUEENS      RESIDENCE - APT. HOUSE   61093.0      94434.0
# 9         BROOKLYN             RESIDENCE-HOUSE   59849.0      84687.0
# 10        BROOKLYN  RESIDENCE - PUBLIC HOUSING   39054.0      86229.0
# 11       MANHATTAN  RESIDENCE - PUBLIC HOUSING   28261.0      89022.0
# 12       MANHATTAN         COMMERCIAL BUILDING   26028.0      33713.0
# 13       MANHATTAN        TRANSIT - NYC SUBWAY   23095.0      34960.0
# 14           BRONX  RESIDENCE - PUBLIC HOUSING   22847.0      82602.0
# 15   STATEN ISLAND             RESIDENCE-HOUSE   20061.0      51116.0
# 16       MANHATTAN              BAR/NIGHT CLUB   19536.0      17090.0
# 17           BRONX             RESIDENCE-HOUSE   18447.0      36384.0
# 18   STATEN ISLAND                      STREET   17066.0      47312.0
# 19       MANHATTAN            RESTAURANT/DINER   16390.0      16023.0
# 20        BROOKLYN                       OTHER   13036.0      25754.0
# 21           BRONX                       OTHER   12997.0      22451.0
# 22        BROOKLYN        TRANSIT - NYC SUBWAY   12878.0      17530.0
# 23        BROOKLYN         COMMERCIAL BUILDING   10732.0      18900.0
# 24       MANHATTAN                 CHAIN STORE   10662.0      38525.0
# 25       MANHATTAN                       OTHER    9889.0      20411.0
# 26       MANHATTAN            DEPARTMENT STORE    9409.0      36747.0
# 27          QUEENS         COMMERCIAL BUILDING    9382.0      15622.0
# 28          QUEENS  RESIDENCE - PUBLIC HOUSING    9022.0      16693.0
# 29          QUEENS                       OTHER    8780.0      19086.0
# ..             ...                         ...       ...          ...
# 325          BRONX                  PHOTO/COPY      19.0         34.0
# 326  STATEN ISLAND                   BOOK/CARD      19.0         57.0
# 327          BRONX                BUS TERMINAL      18.0         24.0
# 328       BROOKLYN                BUS TERMINAL      17.0         37.0
# 329  STATEN ISLAND    TAXI/LIVERY (UNLICENSED)      17.0          4.0
# 330      MANHATTAN                    CEMETERY      16.0         39.0
# 331  STATEN ISLAND                 VIDEO STORE      15.0         53.0
# 332  STATEN ISLAND                BUS TERMINAL      15.0         45.0
# 333  STATEN ISLAND                      TUNNEL      14.0         80.0
# 334  STATEN ISLAND                        SHOE      14.0         58.0
# 335      MANHATTAN                     TRAMWAY      13.0         16.0
# 336          BRONX                   BOOK/CARD      12.0         59.0
# 337      MANHATTAN            AIRPORT TERMINAL      11.0          3.0
# 338  STATEN ISLAND                   SYNAGOGUE      11.0         18.0
# 339       BROOKLYN            AIRPORT TERMINAL      10.0         12.0
# 340         QUEENS                     TRAMWAY      10.0         13.0
# 341       BROOKLYN        FERRY/FERRY TERMINAL       9.0          2.0
# 342  STATEN ISLAND      TAXI (YELLOW LICENSED)       7.0         25.0
# 343  STATEN ISLAND      OTHER HOUSE OF WORSHIP       7.0         26.0
# 344          BRONX                     TRAMWAY       7.0         13.0
# 345          BRONX            AIRPORT TERMINAL       6.0          7.0
# 346  STATEN ISLAND                LOAN COMPANY       6.0         15.0
# 347       BROOKLYN                     TRAMWAY       6.0         33.0
# 348  STATEN ISLAND                  PHOTO/COPY       5.0          9.0
# 349  STATEN ISLAND            AIRPORT TERMINAL       3.0          3.0
# 350  STATEN ISLAND                      MOSQUE       3.0          9.0
# 351         QUEENS        FERRY/FERRY TERMINAL       1.0          2.0
# 352  STATEN ISLAND        TRANSIT - NYC SUBWAY       1.0          NaN
# 353  STATEN ISLAND                     TRAMWAY       NaN          2.0
# 354          BRONX        FERRY/FERRY TERMINAL       NaN          2.0
#
#      Violation
# 0      47122.0
# 1      31431.0
# 2      32087.0
# 3      76582.0
# 4      32266.0
# 5      49694.0
# 6      67824.0
# 7      44404.0
# 8      43255.0
# 9      33997.0
# 10     22894.0
# 11     20089.0
# 12      6318.0
# 13      4498.0
# 14     16126.0
# 15     23555.0
# 16      2397.0
# 17     15027.0
# 18      8900.0
# 19      2886.0
# 20      5835.0
# 21      4733.0
# 22      2308.0
# 23      4522.0
# 24      1611.0
# 25      4463.0
# 26       605.0
# 27      3729.0
# 28      6573.0
# 29      3853.0
# ..         ...
# 325        4.0
# 326        7.0
# 327        8.0
# 328       19.0
# 329        3.0
# 330        1.0
# 331        1.0
# 332       22.0
# 333       13.0
# 334        5.0
# 335        NaN
# 336       11.0
# 337        NaN
# 338        3.0
# 339        2.0
# 340        NaN
# 341        2.0
# 342        2.0
# 343        2.0
# 344        NaN
# 345        3.0
# 346        6.0
# 347        2.0
# 348        4.0
# 349        1.0
# 350        5.0
# 351        NaN
# 352        NaN
# 353        NaN
# 354        1.0
#
# [355 rows x 5 columns]
