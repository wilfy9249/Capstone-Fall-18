# %%
# Data exploration
import pandas as pd

# Numerical
import numpy as np

import os
print(os.listdir("../"))

df = pd.read_csv('../wilfr/NYPD_Complaint_Data_Historic (1).csv', low_memory=False)
df[:5]
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'MSSQLSERVER', 'Public', 'SQLTELEMETRY', 'wilfr']
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# ...

# %%
# Visualisations
import matplotlib.pyplot as plt 
import matplotlib
#import plotly
import plotly.offline as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from plotly.tools import make_subplots
init_notebook_mode()

import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline
# Warnings
import warnings
warnings.filterwarnings('ignore')

# Data exploration
import pandas as pd

# Numerical
import numpy as np

# Spatial analysis
import geopandas as gpd   # used to read .shp file
from shapely.geometry import Point, Polygon, shape

import os
print(os.listdir("../"))

df = pd.read_csv('../wilfr/NYPD_Complaint_Data_Historic (1).csv', low_memory=False)
df[:5]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-acecb6c675df> in <module>()
#       3 import matplotlib
#       4 #import plotly
# ----> 5 import plotly.offline as py
#       6 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#       7 import plotly.graph_objs as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Data exploration
import pandas as pd

# Numerical
import numpy as np

import os
print(os.listdir("../wilfr"))

df = pd.read_csv('../wilfr/NYPD_Complaint_Data_Historic (1).csv', low_memory=False)
df[:5]
# Out:
# ['.anaconda', '.cisco', '.conda', '.condarc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.PhpStorm2017.3', '.PhpStorm2018.1', '.PhpStorm2018.2', '.RapidMiner', '.spyder-py3', '.ssh', '.vscode', '3D Objects', 'Anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'MicrosoftEdgeBackups', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{fb9f4219-53c6-11e8-b0d7-f894c213dba6}.TM.blf', 'NTUSER.DAT{fb9f4219-53c6-11e8-b0d7-f894c213dba6}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{fb9f4219-53c6-11e8-b0d7-f894c213dba6}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'NYPD_Complaint_Data_Historic (1).csv', 'OneDrive', 'PhpstormProjects', 'Pictures', 'Practice-10Oct.ipynb', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Videos']
# ...
